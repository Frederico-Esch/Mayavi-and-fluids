# %%
import numpy as np
from mayavi import mlab

# %%
# %gui qt

# %%
Xspace = np.linspace(0, 2, 50)
Yspace = np.linspace(-2, 2, 100)
Zspace = np.linspace(-1, 2, 75)
X, Y, Z = np.meshgrid(Xspace, Yspace, Zspace)

# %%
t = np.linspace(0, 2*np.pi, 50)
u = np.cos(t)*np.pi
x,y,z = np.sin(u), np.cos(u), np.sin(t)

# %%
mlab.points3d(x,y,z)

# %%
mlab.points3d(x,y,z,t, scale_mode="none")

# %%
mlab.points3d(x,y,z,t)

# %%
mlab.plot3d(x,y,z,t)

# %% [markdown]
# # Espherical spring, ball in the end

# %%
t = np.linspace(0, 2*np.pi*2, 100)
x = np.sin(t)
y = np.cos(t)
z = t/10

# %%
mlab.plot3d(x,y,z)
mlab.points3d([0],[1],[0])

# %% [markdown]
# # mesh

# %%
space = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(space, space)
Z = np.sin(X**2 + Y**2)

# %%
mlab.surf(space, space, Z)
mlab.mesh(X, Y, Z)

# %% [markdown]
# # Sphere

# %%
Xspace = np.linspace(0, np.pi, 5)
Yspace = np.linspace(0, 2*np.pi, 5)
X, Y = np.meshgrid(Xspace, Yspace)

# %%
x1, y1, z1 = 0, 1, 0
x2, y2, z2 = 1, 0, 1
x3, y3, z3 = 0, 0, -1
x4, y4, z4 = -1, 0, 1

mlab.mesh(
    [[x1, x2, x4],
     [x4, x3, x1],
     [x2, x2, x2]],
    [[y1, y2, y4],
     [y4, y3, y1],
     [y2, y2, y2]],
    [[z1, z2, z4],
     [z4, z3, z1],
     [z2, z2, z2]],
    color=(1,0,0)
)
#mlab.points3d(x1, y1, z1)

# %%
mlab.surf(Xspace, Yspace, np.sin(X)*np.sin(Y))

# %%
mlab.mesh(np.sin(X)*np.cos(Y), np.sin(X)*np.sin(Y), np.cos(X))

# %% [markdown]
# # Stream

# %%
x, y, z = np.mgrid[-2:3:10j, -2:3:10j, -2:3:10j]
r = np.sqrt(x**2 + y**2 + z**4)
u = y * np.sin(r)/(r+.001)
v = -x * np.sin(r)/(r+.001)
w = np.zeros_like(z)+(np.random.rand(*z.shape)*.5)
mlab.flow(x, y, z, u, v, w, seedtype='plane')

# %% [markdown]
# # Lorenz equations

# %% [markdown]
# $$
# \frac{dx}{dt} = s(y-x)
# $$
# $$
# \frac{dy}{dt} = rx-y-xz
# $$
# $$
# \frac{dz}{dt} = xy-bz
# $$
#
# let $s=10$, $r=28$ and $b = \frac{8}{3}$

# %%
def lorenz(x, y, z):
    u = 10*(y-x)
    v = 28*x - y -x*z
    w = x*y -8/3*z
    return u,v,w

# %%
x, y, z = np.mgrid[-50:50:20j, -50:50:20j, -10:60:20j]
u,v,w = lorenz(x,y,z)

# %%
mlab.quiver3d(x,y,z,u,v,w, scale_factor=0.005, mask_points=10)

# %%
mlab.flow(x,y,z,u,v,w)

# %% [markdown]
# # Same particle (10,50,50) for 50 sec

# %%
from scipy.integrate import odeint

# %%
def integrating_lorenz(state, t):
    x,y,z = state
    return np.array(lorenz(x,y,z))
time = np.linspace(0, 50, 1000)
sol = odeint(integrating_lorenz, (10, 50, 50), time)
mlab.plot3d(*sol.T, representation="wireframe", color=(1,0,0), line_width=1.5)

# %% [markdown]
# # Moving Wave

# %%
@mlamlabanimate(delay=100)
def anim():
    x,y = np.mgrid[-3:3:100j, -3:3:100j]
    z = np.sin(x**2 + y**2)
    s = mlab.surf(x,y,z)
    mlab.axes()
    for i in range(100):
        s.mlab_source.set(
            scalars=np.sin((x*i*0.01)**2 + (y*i*0.01))
        )
        mlab.process_ui_events()
        yield
anim()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4452/1136001782.py in <module>
#      12         yield
#      13 anim()
# ---> 14 mlab.show()
#
# E:\Progs\Python\lib\site-packages\mayavi\tools\show.py in show(func, stop)
#     122             if stop:
#     123                 _stop_show = StopShow()
# --> 124             g.start_event_loop()
#     125         return
#     126
#
# E:\Progs\Python\lib\site-packages\pyface\ui\qt4\gui.py in start_event_loop(self)
#     104
#     105         logger.debug("---------- starting GUI event loop ----------")
# --> 106         start_event_loop_qt4()
#     107
#     108         self.started = False
#
# E:\Progs\Python\lib\site-packages\pyface\util\guisupport.py in start_event_loop_qt4(app)
#     153     if not is_event_loop_running_qt4(app):
#     154         app._in_event_loop = True
# --> 155         app.exec_()
#     156         app._in_event_loop = False
#     157     else:
#
# KeyboardInterrupt:

# %%
s = ml
